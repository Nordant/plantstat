# %%
import numpy as np
from scipy.stats import *

# ignoring warnings
import warnings
warnings.simplefilter("ignore")

from plantstat import Variable_Analyzer

# %% [markdown]
# ## Example of the data

# %%
data = np.array([[54, 27, 43, 30, 29, 23, 71, 68, 64, 66, 64, 70, 49, 49, 
                 55, 45, 48, 49, 38],
                [53, 43, 55, 63, 82, 79, 70, 57, 60, 43, 49, 65, 54],
                [53, 43, 46, 74, 57, 66, 72, 38, 45, 63, 56, 58, 57, 39, 
                 35, 64, 45, 52],
                [36, 45, 23, 83, 70, 82, 77, 41, 37, 48, 55, 52, 22],
                [35, 42, 49, 74, 83, 73, 68, 60, 45, 70, 52, 72, 59, 48, 
                 62, 72, 62, 38]])
labels = ['Control', 'Var1', 'Var2', 'Var3', 'Var4']

# %% [markdown]
# ## Define Analyzer

# %%
a = Variable_Analyzer(data, labels)

# %% [markdown]
# ## Stat functions

# %%
# All means
a.stat(np.mean)
# Out:
# [49.578947368421055,
#  59.46153846153846,
#  53.5,
#  51.61538461538461,
#  59.111111111111114]

# %%
# All interquartile ranges
a.stat(iqr)
# Out:
# [23.5, 12.0, 16.75, 33.0, 23.25]

# %%
a.labels
# Out:
# ['Control', 'Var1', 'Var2', 'Var3', 'Var4']

# %% [markdown]
# ## Outliers

# %%
a.outliers()
# Out:
# {'Control': array([], dtype=int32),
#  'Var1': array([82, 79]),
#  'Var2': array([], dtype=int32),
#  'Var3': array([], dtype=int32),
#  'Var4': array([], dtype=int32)}

# %% [markdown]
# ## Boxplots

# %%
a.boxplot()

# %% [markdown]
# ## Variables length

# %%
a.var_len()
# Out:
# [19, 13, 18, 13, 18]

# %% [markdown]
# ## Basic statistics

# %%
a.basic_stats()
# Out:
#   variable    mean  trim_mean  median     std   min   max    iqr  shapiro_p  \
# 0  Control  49.579     49.882    49.0  14.823  23.0  71.0  23.50      0.251
# 1     Var1  59.462     58.909    57.0  11.745  43.0  82.0  12.00      0.576
# 2     Var2  53.500     53.375    54.5  11.246  35.0  74.0  16.75      0.720
# 3     Var3  51.615     51.455    48.0  20.048  22.0  83.0  33.00      0.351
# 4     Var4  59.111     59.125    61.0  13.597  35.0  83.0  23.25      0.519
#
#    normtest_p
# 0       0.404
# 1       0.674
# 2       0.613
# 3       0.531
# 4       0.434

# %% [markdown]
# ## Compare pairs of variables

# %%
a.var_compare()
# Out:
#              pair    shape  bartlet_p  ttest_p  wilcoxon_p  kruskal_p  \
# 0  Control ~ Var1  19 ~ 13      0.421    0.061         NaN      0.111
# 1  Control ~ Var2  19 ~ 18      0.262    0.386         NaN      0.494
# 2  Control ~ Var3  19 ~ 13      0.234    0.751         NaN      0.939
# 3  Control ~ Var4  19 ~ 18      0.727    0.056         NaN      0.078
# 4     Var1 ~ Var2  13 ~ 18      0.839    0.177         NaN      0.262
# 5     Var1 ~ Var3  13 ~ 13      0.076    0.254       0.152      0.200
# 6     Var1 ~ Var4  13 ~ 18      0.622    0.943         NaN      0.984
# 7     Var2 ~ Var3  18 ~ 13      0.029    0.750         NaN      0.589
# 8     Var2 ~ Var4  18 ~ 18      0.442    0.199       0.074      0.217
# 9     Var3 ~ Var4  13 ~ 18      0.137    0.240         NaN      0.271
#
#    mannwhitneyu_p
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN

# %% [markdown]
# ## All variables' pairs

# %%
a.get_pairs()
# Out:
# [('Control', 'Var1'),
#  ('Control', 'Var2'),
#  ('Control', 'Var3'),
#  ('Control', 'Var4'),
#  ('Var1', 'Var2'),
#  ('Var1', 'Var3'),
#  ('Var1', 'Var4'),
#  ('Var2', 'Var3'),
#  ('Var2', 'Var4'),
#  ('Var3', 'Var4')]

# %%
a.get_pairs(indices = True)
# Out:
# [(0, 1),
#  (0, 2),
#  (0, 3),
#  (0, 4),
#  (1, 2),
#  (1, 3),
#  (1, 4),
#  (2, 3),
#  (2, 4),
#  (3, 4)]

# %% [markdown]
# ## Correlation matrix

# %%
a.corrs()
# Out:
#           Control      Var1      Var2      Var3      Var4
# Control  1.000000 -0.298476 -0.124419 -0.302862 -0.134419
# Var1    -0.298476  1.000000  0.406320  0.630612  0.651370
# Var2    -0.124419  0.406320  1.000000  0.728234  0.542800
# Var3    -0.302862  0.630612  0.728234  1.000000  0.676433
# Var4    -0.134419  0.651370  0.542800  0.676433  1.000000

# %%
a.corrs(method = 'pearson', heatmap = True)
# Out:
#           Control      Var1      Var2      Var3      Var4
# Control  1.000000 -0.298476 -0.124419 -0.302862 -0.134419
# Var1    -0.298476  1.000000  0.406320  0.630612  0.651370
# Var2    -0.124419  0.406320  1.000000  0.728234  0.542800
# Var3    -0.302862  0.630612  0.728234  1.000000  0.676433
# Var4    -0.134419  0.651370  0.542800  0.676433  1.000000

# %% [markdown]
# # Q-Q plots

# %%
a.QQplot()

# %% [markdown]
# ## Pair plot

# %%
a.pair_plot()
